# %% [markdown]
# # FRED 경제데이터 가져오기
# ## FRED : Federal Reserve Economic Data

# %% [markdown]
# https://en.wikipedia.org/wiki/Federal_Reserve_Economic_Data

# %% [markdown]
# https://fred.stlouisfed.org

# %% [markdown]
# https://pandas-datareader.readthedocs.io/en/latest/remote_data.html

# %%
# FRED(Federal Reserve Economic Data) 세인트루이스 연준 관리 경제통계 데이터베이스
# 각 항목별 티커를 찾는 방법
# FRED 웹사이트(https://fred.stlouisfed.org/) 에서 원하는 데이터를 검색
# /series/ 다음에 위치하는 DEXKOUS가 해당 항목의 티커

# %% [markdown]
# https://fred.stlouisfed.org/series/GDP

# %% [markdown]
# ## 미국 GDP(GDP)

# %%
# 미국 GDP(GDP)

import pandas_datareader as pdr

data1 = pdr.DataReader('GDP', 'fred', '2000-01-01')
data1.head(10)
# Out:
#                   GDP
# DATE
# 2000-01-01  10002.179
# 2000-04-01  10247.720
# 2000-07-01  10318.165
# 2000-10-01  10435.744
# 2001-01-01  10470.231
# 2001-04-01  10599.000
# 2001-07-01  10598.020
# 2001-10-01  10660.465
# 2002-01-01  10783.500
# 2002-04-01  10887.460

# %%
# 미국 GDP(GDP)
import pandas_datareader as pdr

data1 = pdr.DataReader('GDP', 'fred', '1990-01-01')
data1.head(10)
# Out:
#                  GDP
# DATE
# 1990-01-01  5872.701
# 1990-04-01  5960.028
# 1990-07-01  6015.116
# 1990-10-01  6004.733
# 1991-01-01  6035.178
# 1991-04-01  6126.862
# 1991-07-01  6205.937
# 1991-10-01  6264.540
# 1992-01-01  6363.102
# 1992-04-01  6470.763

# %%
# 미국 GDP(GDP)
import pandas_datareader as pdr

data1 = pdr.DataReader('GDP', 'fred', '1990-01-01')
data1.tail(10)
# Out:
#                   GDP
# DATE
# 2020-10-01  21704.706
# 2021-01-01  22313.850
# 2021-04-01  23046.934
# 2021-07-01  23550.420
# 2021-10-01  24349.121
# 2022-01-01  24740.480
# 2022-04-01  25248.476
# 2022-07-01  25723.941
# 2022-10-01  26137.992
# 2023-01-01  26486.287

# %%
# 장단기금리차 : 10년국채수익률 - 2년물 국채수익률

import pandas_datareader as pdr

data2 = pdr.DataReader('T10Y2Y', 'fred', '2000-01-01')
data2.head(10)
# Out:
#             T10Y2Y
# DATE
# 2000-01-03    0.20
# 2000-01-04    0.19
# 2000-01-05    0.24
# 2000-01-06    0.22
# 2000-01-07    0.21
# 2000-01-10    0.19
# 2000-01-11    0.22
# 2000-01-12    0.23
# 2000-01-13    0.23
# 2000-01-14    0.25

# %%
import matplotlib.pyplot as plt
data2.plot(figsize=(10, 6))
plt.show()

# %%
import pandas_datareader.data as web
from pandas_datareader import wb
import datetime

start = datetime.datetime(2020, 1, 1)
end = datetime.datetime(2023, 5, 1)
gdp = web.DataReader('GDP', 'fred', start, end)

# %%
gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 13 entries, 2020-01-01 to 2023-01-01
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   GDP     13 non-null     float64
# dtypes: float64(1)
# memory usage: 208.0 bytes

# %%
gdp
# Out:
#                   GDP
# DATE
# 2020-01-01  21538.032
# 2020-04-01  19636.731
# 2020-07-01  21362.428
# 2020-10-01  21704.706
# 2021-01-01  22313.850
# 2021-04-01  23046.934
# 2021-07-01  23550.420
# 2021-10-01  24349.121
# 2022-01-01  24740.480
# 2022-04-01  25248.476
# 2022-07-01  25723.941
# 2022-10-01  26137.992
# 2023-01-01  26486.287

# %%
gdp.head(10)
# Out:
#                   GDP
# DATE
# 2020-01-01  21538.032
# 2020-04-01  19636.731
# 2020-07-01  21362.428
# 2020-10-01  21704.706
# 2021-01-01  22313.850
# 2021-04-01  23046.934
# 2021-07-01  23550.420
# 2021-10-01  24349.121
# 2022-01-01  24740.480
# 2022-04-01  25248.476

# %%
# GDP 기초통계량 
gdp.describe()
# Out:
#                 GDP
# count     13.000000
# mean   23526.107538
# std     2127.442776
# min    19636.731000
# 25%    21704.706000
# 50%    23550.420000
# 75%    25248.476000
# max    26486.287000

# %%
gdp.loc['2021-01-01']
# Out:
# GDP    22313.85
# Name: 2021-01-01 00:00:00, dtype: float64

# %%
# 여러 국가 가져오기
dat = wb.download(indicator='NY.GDP.PCAP.KD', country=['US', 'CA', 'MX'], start=2015, end=2021)
dat
# Out:
#                     NY.GDP.PCAP.KD
# country       year
# Canada        2021    43936.308105
#               2020    42258.691017
#               2019    45109.244486
#               2018    44917.483728
#               2017    44325.488337
#               2016    43536.913403
#               2015    43596.135537
# Mexico        2021     9525.409684
#               2020     9147.053505
#               2019    10013.703192
#               2018    10120.363543
#               2017     9997.686914
#               2016     9897.150062
#               2015     9753.380048
# United States 2021    61855.518630
#               2020    58453.446128
#               2019    60698.011299
#               2018    59607.393660
#               2017    58207.578310
#               2016    57292.538783
#               2015    56762.729452

# %%
dat = wb.download(indicator='NY.GDP.PCAP.KD', country=['US', 'CA', 'MX'], start=2015, end=2021)
print(dat)
# Out:
#                     NY.GDP.PCAP.KD
# country       year
# Canada        2021    43936.308105
#               2020    42258.691017
#               2019    45109.244486
#               2018    44917.483728
#               2017    44325.488337
#               2016    43536.913403
#               2015    43596.135537
# Mexico        2021     9525.409684
#               2020     9147.053505
#               2019    10013.703192
#               2018    10120.363543
#               2017     9997.686914
#               2016     9897.150062
#               2015     9753.380048
# United States 2021    61855.518630
#               2020    58453.446128
#               2019    60698.011299
#               2018    59607.393660
#               2017    58207.578310
#               2016    57292.538783
#               2015    56762.729452

# %%
dat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 21 entries, ('Canada', '2021') to ('United States', '2015')
# Data columns (total 1 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   NY.GDP.PCAP.KD  21 non-null     float64
# dtypes: float64(1)
# memory usage: 807.0+ bytes

# %% [markdown]
# ## 인플레이션

# %%
# 인플레이션
# 소비자 가격 지수(CPIAUCSL)
# 식료품 및 연료를 제외한 소비자 가격 지수(CPILFESL)

# https://fred.stlouisfed.org/series/CPIAUCSL

# https://fred.stlouisfed.org/series/CPILFESL

inflation = web.DataReader(['CPIAUCSL', 'CPILFESL'], 'fred', start, end)
inflation
# Out:
#             CPIAUCSL  CPILFESL
# DATE
# 2020-01-01   259.037   266.626
# 2020-02-01   259.248   267.283
# 2020-03-01   258.124   267.090
# 2020-04-01   256.092   265.771
# 2020-05-01   255.868   265.574
# 2020-06-01   256.986   265.952
# 2020-07-01   258.278   267.352
# 2020-08-01   259.411   268.469
# 2020-09-01   260.029   268.938
# 2020-10-01   260.286   269.236
# 2020-11-01   260.813   269.901
# 2020-12-01   262.035   270.267
# 2021-01-01   262.650   270.383
# 2021-02-01   263.638   270.727
# 2021-03-01   264.914   271.526
# 2021-04-01   266.670   273.615
# 2021-05-01   268.444   275.654
# 2021-06-01   270.559   277.676
# 2021-07-01   271.764   278.522
# 2021-08-01   272.870   279.057
# 2021-09-01   274.028   279.755
# 2021-10-01   276.522   281.588
# 2021-11-01   278.711   283.340
# 2021-12-01   280.887   285.193
# 2022-01-01   282.599   286.792
# 2022-02-01   284.610   288.147
# 2022-03-01   287.472   289.046
# 2022-04-01   288.611   290.410
# 2022-05-01   291.268   292.251
# 2022-06-01   294.728   294.017
# 2022-07-01   294.628   294.925
# 2022-08-01   295.320   296.639
# 2022-09-01   296.539   298.339
# 2022-10-01   297.987   299.333
# 2022-11-01   298.598   300.261
# 2022-12-01   298.990   301.460
# 2023-01-01   300.536   302.702
# 2023-02-01   301.648   304.070
# 2023-03-01   301.808   305.240
# 2023-04-01   302.918   306.489

# %%
inflation.head()
# Out:
#             CPIAUCSL  CPILFESL
# DATE
# 2020-01-01   259.037   266.626
# 2020-02-01   259.248   267.283
# 2020-03-01   258.124   267.090
# 2020-04-01   256.092   265.771
# 2020-05-01   255.868   265.574

# %%
from pandas_datareader import wb
matches = wb.search('gdp.*capita.*const')
matches
# Out:
#                          id  \
# 691      6.0.GDPpc_constant
# 10634        NY.GDP.PCAP.KD
# 10636        NY.GDP.PCAP.KN
# 10638     NY.GDP.PCAP.PP.KD
# 10639  NY.GDP.PCAP.PP.KD.87
#
#                                                     name unit  \
# 691    GDP per capita, PPP (constant 2011 internation...
# 10634                 GDP per capita (constant 2015 US$)
# 10636                      GDP per capita (constant LCU)
# 10638  GDP per capita, PPP (constant 2017 internation...
# 10639  GDP per capita, PPP (constant 1987 internation...
#
#                              source  \
# 691                  LAC Equity Lab
# 10634  World Development Indicators
# 10636  World Development Indicators
# 10638  World Development Indicators
# 10639         WDI Database Archives
#
#                                               sourceNote  \
# 691    GDP per capita based on purchasing power parit...
# 10634  GDP per capita is gross domestic product divid...
# 10636  GDP per capita is gross domestic product divid...
# 10638  GDP per capita based on purchasing power parit...
# 10639
#
#                                       sourceOrganization            topics
# 691         b'World Development Indicators (World Bank)'  Economy & Growth
# 10634  b'World Bank national accounts data, and OECD ...  Economy & Growth
# 10636  b'World Bank national accounts data, and OECD ...  Economy & Growth
# 10638  b'International Comparison Program, World Bank...  Economy & Growth
# 10639                                                b''

# %%
import requests
import json
data = requests.get('https://api.stlouisfed.org/fred/series?series_id=GNPCA&api_key=43be4fc471782325cab7d47238bf8962&file_type=json')

# %%
data.json()
# Out:
# {'realtime_start': '2023-05-30',
#  'realtime_end': '2023-05-30',
#  'seriess': [{'id': 'GNPCA',
#    'realtime_start': '2023-05-30',
#    'realtime_end': '2023-05-30',
#    'title': 'Real Gross National Product',
#    'observation_start': '1929-01-01',
#    'observation_end': '2022-01-01',
#    'frequency': 'Annual',
#    'frequency_short': 'A',
#    'units': 'Billions of Chained 2012 Dollars',
#    'units_short': 'Bil. of Chn. 2012 $',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2023-03-30 07:54:21-05',
#    'popularity': 7,
#    'notes': 'BEA Account Code: A001RX\n\n'}]}

# %%
# datapungi_fed  설치 필요
# !pip install datapungi_fed
# Out:
# Requirement already satisfied: datapungi_fed in c:\users\jyb\anaconda3\lib\site-packages (0.3.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\jyb\anaconda3\lib\site-packages (from datapungi_fed) (4.11.1)
# Requirement already satisfied: pyperclip in c:\users\jyb\anaconda3\lib\site-packages (from datapungi_fed) (1.8.2)
# Requirement already satisfied: requests in c:\users\jyb\anaconda3\lib\site-packages (from datapungi_fed) (2.28.1)
# Requirement already satisfied: pyyaml in c:\users\jyb\anaconda3\lib\site-packages (from datapungi_fed) (6.0)
# Requirement already satisfied: pandas in c:\users\jyb\anaconda3\lib\site-packages (from datapungi_fed) (1.4.4)
# Requirement already satisfied: html5lib in c:\users\jyb\anaconda3\lib\site-packages (from datapungi_fed) (1.1)
# Requirement already satisfied: lxml in c:\users\jyb\anaconda3\lib\site-packages (from datapungi_fed) (4.9.1)
# Requirement already satisfied: pytest-html in c:\users\jyb\anaconda3\lib\site-packages (from datapungi_fed) (3.2.0)
# Requirement already satisfied: pytest in c:\users\jyb\anaconda3\lib\site-packages (from datapungi_fed) (7.1.2)
# Requirement already satisfied: xlrd in c:\users\jyb\anaconda3\lib\site-packages (from datapungi_fed) (2.0.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\jyb\anaconda3\lib\site-packages (from beautifulsoup4->datapungi_fed) (2.3.1)
# Requirement already satisfied: webencodings in c:\users\jyb\anaconda3\lib\site-packages (from html5lib->datapungi_fed) (0.5.1)
# Requirement already satisfied: six>=1.9 in c:\users\jyb\anaconda3\lib\site-packages (from html5lib->datapungi_fed) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\jyb\anaconda3\lib\site-packages (from pandas->datapungi_fed) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jyb\anaconda3\lib\site-packages (from pandas->datapungi_fed) (2023.3)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\jyb\anaconda3\lib\site-packages (from pandas->datapungi_fed) (1.21.5)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\jyb\anaconda3\lib\site-packages (from pytest->datapungi_fed) (21.4.0)
# Requirement already satisfied: iniconfig in c:\users\jyb\anaconda3\lib\site-packages (from pytest->datapungi_fed) (1.1.1)
# Requirement already satisfied: packaging in c:\users\jyb\anaconda3\lib\site-packages (from pytest->datapungi_fed) (21.3)
# Requirement already satisfied: pluggy<2.0,>=0.12 in c:\users\jyb\anaconda3\lib\site-packages (from pytest->datapungi_fed) (1.0.0)
# Requirement already satisfied: py>=1.8.2 in c:\users\jyb\anaconda3\lib\site-packages (from pytest->datapungi_fed) (1.11.0)
# Requirement already satisfied: tomli>=1.0.0 in c:\users\jyb\anaconda3\lib\site-packages (from pytest->datapungi_fed) (2.0.1)
# Requirement already satisfied: atomicwrites>=1.0 in c:\users\jyb\anaconda3\lib\site-packages (from pytest->datapungi_fed) (1.4.0)
# Requirement already satisfied: colorama in c:\users\jyb\anaconda3\lib\site-packages (from pytest->datapungi_fed) (0.4.5)
# Requirement already satisfied: pytest-metadata in c:\users\jyb\anaconda3\lib\site-packages (from pytest-html->datapungi_fed) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jyb\anaconda3\lib\site-packages (from requests->datapungi_fed) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\jyb\anaconda3\lib\site-packages (from requests->datapungi_fed) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jyb\anaconda3\lib\site-packages (from requests->datapungi_fed) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jyb\anaconda3\lib\site-packages (from requests->datapungi_fed) (2023.5.7)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\jyb\anaconda3\lib\site-packages (from packaging->pytest->datapungi_fed) (3.0.9)

# %%
# !pytest
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.9.6, pytest-6.2.5, py-1.11.0, pluggy-1.0.0
# rootdir: C:\finance_data\금융DT
# plugins: dash-1.21.0, html-3.1.1, metadata-1.11.0
# collected 0 items
#
# ============================ no tests ran in 0.03s ============================

# %% [markdown]
# # FRED에서 API 경제데이터 가져오기

# %%
# 설치하기
# !pip install fredapi
# Out:
# Requirement already satisfied: fredapi in c:\users\jyb\anaconda3\lib\site-packages (0.5.0)
# Requirement already satisfied: pandas in c:\users\jyb\anaconda3\lib\site-packages (from fredapi) (1.4.4)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\jyb\anaconda3\lib\site-packages (from pandas->fredapi) (1.21.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jyb\anaconda3\lib\site-packages (from pandas->fredapi) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\jyb\anaconda3\lib\site-packages (from pandas->fredapi) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\jyb\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->fredapi) (1.16.0)

# %%
# API 발급을 위해서 회원가입 주석

# %%
from fredapi import Fred
fred = Fred(api_key='fd1643976833c89506544ff62efd7f70')
data = fred.get_series('GDP')

# %%
# GDP 가져오기
data = fred.get_series_first_release('GDP')
data.tail(10)
# Out:
# date
# 2020-10-01    21479.529
# 2021-01-01    22048.894
# 2021-04-01    22722.581
# 2021-07-01    23173.496
# 2021-10-01    23992.355
# 2022-01-01    24382.683
# 2022-04-01    24851.809
# 2022-07-01    25663.289
# 2022-10-01    26132.458
# 2023-01-01    26465.865
# Name: value, dtype: object

# %%
data = fred.get_series_latest_release('GDP')
data
# Out:
# 1946-01-01          NaN
# 1946-04-01          NaN
# 1946-07-01          NaN
# 1946-10-01          NaN
# 1947-01-01      243.164
#                 ...
# 2022-01-01    24740.480
# 2022-04-01    25248.476
# 2022-07-01    25723.941
# 2022-10-01    26137.992
# 2023-01-01    26486.287
# Length: 309, dtype: float64

# %%
fred.get_series_as_of_date('GDP', '6/1/2019')
# Out:
#      realtime_start       date      value
# 0        1992-12-22 1946-01-01      199.7
# 1        1996-01-19 1946-01-01        NaT
# 2        1997-05-07 1946-01-01      210.4
# 3        1999-10-28 1946-01-01        NaT
# 4        1992-12-22 1946-04-01      207.7
# ...             ...        ...        ...
# 3017     2018-12-21 2018-07-01  20658.204
# 3022     2019-02-28 2018-10-01  20891.367
# 3023     2019-03-28 2018-10-01   20865.14
# 3028     2019-04-26 2019-01-01  21062.691
# 3029     2019-05-30 2019-01-01  21048.839
#
# [2906 rows x 3 columns]

# %%
df = fred.get_series_all_releases('GDP')
df.tail()
# Out:
#      realtime_start       date      value
# 3101     2023-01-26 2022-10-01  26132.458
# 3102     2023-02-23 2022-10-01  26144.956
# 3103     2023-03-30 2022-10-01  26137.992
# 3104     2023-04-27 2023-01-01  26465.865
# 3105     2023-05-25 2023-01-01  26486.287

# %%
import pandas_datareader as pdr
pdr.get_data_fred('GS10')
# Out:
#             GS10
# DATE
# 2018-06-01  2.91
# 2018-07-01  2.89
# 2018-08-01  2.89
# 2018-09-01  3.00
# 2018-10-01  3.15
# 2018-11-01  3.12
# 2018-12-01  2.83
# 2019-01-01  2.71
# 2019-02-01  2.68
# 2019-03-01  2.57
# 2019-04-01  2.53
# 2019-05-01  2.40
# 2019-06-01  2.07
# 2019-07-01  2.06
# 2019-08-01  1.63
# 2019-09-01  1.70
# 2019-10-01  1.71
# 2019-11-01  1.81
# 2019-12-01  1.86
# 2020-01-01  1.76
# 2020-02-01  1.50
# 2020-03-01  0.87
# 2020-04-01  0.66
# 2020-05-01  0.67
# 2020-06-01  0.73
# 2020-07-01  0.62
# 2020-08-01  0.65
# 2020-09-01  0.68
# 2020-10-01  0.79
# 2020-11-01  0.87
# 2020-12-01  0.93
# 2021-01-01  1.08
# 2021-02-01  1.26
# 2021-03-01  1.61
# 2021-04-01  1.64
# 2021-05-01  1.62
# 2021-06-01  1.52
# 2021-07-01  1.32
# 2021-08-01  1.28
# 2021-09-01  1.37
# 2021-10-01  1.58
# 2021-11-01  1.56
# 2021-12-01  1.47
# 2022-01-01  1.76
# 2022-02-01  1.93
# 2022-03-01  2.13
# 2022-04-01  2.75
# 2022-05-01  2.90
# 2022-06-01  3.14
# 2022-07-01  2.90
# 2022-08-01  2.90
# 2022-09-01  3.52
# 2022-10-01  3.98
# 2022-11-01  3.89
# 2022-12-01  3.62
# 2023-01-01  3.53
# 2023-02-01  3.75
# 2023-03-01  3.66
# 2023-04-01  3.46

# %%
# 날짜는 datetime 패키지를 사용하여 지정
# 또는 문자열을 바로 사용해도 된다. 

import pandas_datareader.data as web

import datetime

start = datetime.datetime(2015, 1, 1)

end = datetime.datetime(2022, 12, 31)

gdp = web.DataReader('GDP', 'fred', start, end)

gdp.loc['2020-01-01']
# Out:
# GDP    21538.032
# Name: 2020-01-01 00:00:00, dtype: float64

# %% [markdown]
# # 데이터 코드에 리스트를 넣으면 여러개의 데이터를 동시에

# %% [markdown]
# 소비자 가격 지수(CPIAUCSL)
# 식료품 및 연로를 제외한 소비자 가격 지수(CPILFESL)
#
# https://fred.stlouisfed.org/series/CPIAUCSL
#
# https://fred.stlouisfed.org/series/CPILFESL

# %%
# Multiple series:

inflation = web.DataReader(['CPIAUCSL', 'CPILFESL'], 'fred', start, end)

inflation.head()
# Out:
#             CPIAUCSL  CPILFESL
# DATE
# 2015-01-01   234.747   239.811
# 2015-02-01   235.342   240.172
# 2015-03-01   235.976   240.755
# 2015-04-01   236.222   241.346
# 2015-05-01   237.001   241.688

# %%
inflation.tail()
# Out:
#             CPIAUCSL  CPILFESL
# DATE
# 2022-08-01   295.320   296.639
# 2022-09-01   296.539   298.339
# 2022-10-01   297.987   299.333
# 2022-11-01   298.598   300.261
# 2022-12-01   298.990   301.460

# %%
# 컬럼데이터 일부만 축출

CPIAUCSL = inflation['CPIAUCSL']
print(CPIAUCSL)
# Out:
# DATE
# 2015-01-01    234.747
# 2015-02-01    235.342
# 2015-03-01    235.976
# 2015-04-01    236.222
# 2015-05-01    237.001
#                ...
# 2022-08-01    295.320
# 2022-09-01    296.539
# 2022-10-01    297.987
# 2022-11-01    298.598
# 2022-12-01    298.990
# Name: CPIAUCSL, Length: 96, dtype: float64

# %%
# 시각화 해서 보기

plt.plot(inflation['CPIAUCSL'])
