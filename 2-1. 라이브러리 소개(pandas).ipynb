# %% [markdown]
#  # pandas의 핵심 자료구조
#  ## https://pandas.pydata.org/docs/user_guide/10min.html

# %%
# 테이블 형태(행과 열로 이루어진 데이터 객체)의 데이터 구조와 객체를 편리하게 다루기 위한 패키지
# Pandas 자료구조
# Series: 1차원 벡터 형식
# DataFrame: 2차원 행렬 형식
# Panel: 3차원 배열 형식

# # 데이터 입출력¶
# Pandas는 데이터 파일을 읽어 데이터프레임을 만들 수 있다. 다음처럼 여러가지 포맷을 지원한다.

# CSV : CSV(Comma Separated Value) 포맷 , CSV 파일 포맷은 데이터 값이 쉽표(comma)로 구분되는 텍스트 파일
# Excel
# HTML
# JSON
# HDF5
# SAS
# STATA
# SQL

# %% [markdown]
# ## Series와 DataFrame

# %%
# Pandas 자료구조

# Series: 1차원 벡터 형식 , 하나의 열이 되는 데이터를 리스트나 일차원 배열을 준비한다.
# DataFrame: 2차원 행렬 형식
# Panel: 3차원 배열 형식

# %% [markdown]
# ### Series

# %% [markdown]
# #### (1) 시리즈 이해

# %%
# Series :  1차원 형태의 자료구조
# 파이썬의 리스트와 비슷하고 , 딕셔너리와 유사한 자료구조
# Series모든 데이터 유형(정수, 문자열, 부동 소수점 숫자, Python 객체 등)을 보유할 수 있는 1차원 레이블 배열
# Series형태의 자료구조는 기본적으로 index와 value 가 존재하기 때문에 일반적으로 생각하는 시계열 형태와 일치

# %% [markdown]
# #### (2) 시리즈 생성하기

# %%
# 라이브러리 불러오기
import numpy as np
import pandas as pd

# 판다스로 시리즈 만들기
# 시리즈 인덱스를 따로 지정하지 않으면 0부터 시작한다. 
# 인덱스를 따로 지정하려면 index 인자에 리스트를 전달하면 된다. 
# columns 인자를 사용하면 데이터프레임의 열 순서를 지정할 수 있다.
# 데이터생성하기
stock_list = pd.Series([55000, 80000, 20000],
              index=["삼성전자", "하이닉스", "카카오뱅크"])
stock_list
# Out:
# 삼성전자     55000
# 하이닉스     80000
# 카카오뱅크    20000
# dtype: int64

# %%
# 데이터 타입 알아보기
type(stock_list)
# Out:
# pandas.core.series.Series

# %%
print(stock_list)
# Out:
# 삼성전자     55000
# 하이닉스     80000
# 카카오뱅크    20000
# dtype: int64

# %% [markdown]
# #### (3) 시리즈 구성 확인하기

# %%
# 판다스 패키지의 시리즈 클래스는 dictionary와 비슷한 구조로 index와 values로 구성

# %%
# index 확인
print(stock_list.index)
# Out:
# Index(['삼성전자', '하이닉스', '카카오뱅크'], dtype='object')

# %%
# value 확인
print(stock_list.values)
# Out:
# [55000 80000 20000]

# %% [markdown]
# #### (4) 시리즈 이름 지정

# %%
# 인덱스 이름 지정
# pd.Series()함수의 옵션으로 index명을 지정

stock_list.index.name = "기업명","주가"
stock_list
# Out:
# (기업명, 주가)
# 삼성전자     55000
# 하이닉스     80000
# 카카오뱅크    20000
# dtype: int64

# %% [markdown]
# #### (5) Series를  DataFrame으로 변환 가능

# %%
stock_list.to_frame()
# Out:
#                0
# (기업명, 주가)
# 삼성전자       55000
# 하이닉스       80000
# 카카오뱅크      20000

# %%
df = pd.DataFrame([stock_list])
df
# Out:
# ('기업명', '주가')   삼성전자   하이닉스  카카오뱅크
# 0              55000  80000  20000

# %%
## 시리즈 만들기
from pandas import Series, DataFrame
import pandas as pd
## series
fruit = Series([2500,3800,1200,6000],index=['apple','banana','peer','cherry'])
print(fruit)
# Out:
# apple     2500
# banana    3800
# peer      1200
# cherry    6000
# dtype: int64

# %%
from pandas import Series, DataFrame
# 시리즈생성
abc = Series([600, 590, 570, 550, 570])
print(abc)
# Out:
# 0    600
# 1    590
# 2    570
# 3    550
# 4    570
# dtype: int64

# %%
# Series 객체를 생성할 때 인자로 넘겨준 리스트 내의 데이터 순서 기준으로 인덱싱
print(abc[1])
print(abc[4])
# Out:
# 590
# 570

# %%
# index에 인덱싱할 값을 넘겨주면 해당 값으로 인덱싱
abc1 = Series([600, 590, 570, 550, 570], index=['2020-02-19',
                                                            '2020-02-18',
                                                            '2020-02-17',
                                                            '2020-02-16',
                                                            '2020-02-15'])
print(abc1)
# Out:
# 2020-02-19    600
# 2020-02-18    590
# 2020-02-17    570
# 2020-02-16    550
# 2020-02-15    570
# dtype: int64

# %%
print(abc1['2020-02-16'])
# Out:
# 550

# %%
# 시리즈의 인덱스와 값 확인
for date in abc1.index:
    print(date)

for ending_price in abc1.values:
    print(ending_price)
# Out:
# 2020-02-19
# 2020-02-18
# 2020-02-17
# 2020-02-16
# 2020-02-15
# 600
# 590
# 570
# 550
# 570

# %% [markdown]
# #### (7) 시리즈의 기초 통계 메서드 사용하기

# %%
# describe                요약 통계량 계산
# min                     최솟값 반환
# max                     최댓값 반환
# mean                    산술 평균 반환
# median                  중간값 반환
# std                     표준편차

# %%
print(stock_list.describe())
# Out:
# count        3.000000
# mean     51666.666667
# std      30138.568867
# min      20000.000000
# 25%      37500.000000
# 50%      55000.000000
# 75%      67500.000000
# max      80000.000000
# dtype: float64

# %%
print(stock_list.mean())
# Out:
# 51666.666666666664

# %%
print(stock_list.std())
# Out:
# 30138.56886670854

# %%
print(abc.describe())
# Out:
# count      5.000000
# mean     576.000000
# std       19.493589
# min      550.000000
# 25%      570.000000
# 50%      570.000000
# 75%      590.000000
# max      600.000000
# dtype: float64

# %%
df2 = pd.DataFrame([abc])
print (df2)
# Out:
#      0    1    2    3    4
# 0  600  590  570  550  570

# %%
# # 유용한 메소드

# append                  2개 이상의 시리즈 연결
# drop_duplicates         중복값이 없는 시리즈 반환
# equals                  시리즈에 해당 값을 가진 요소가 있는지 확인
# get_values              시리즈 값 구하기(values 속성과 동일)
# isin                    시리즈에 포함된 값이 있는지 확인

# replace                 특정 값을 가진 시리즈 값을 교체
# sample                  시리즈에서 임이의 값을 반환
# sort_values             값을 정렬
# to_frame                시리즈를 데이터프레임으로 변환

# %% [markdown]
# ## Pandas DataFrame

# %% [markdown]
# ### DataFrame ?

# %%
# DataFrame : 여러 개의 로우(row), 칼럼(Column)으로 구성된 2차원 형태의 자료구조

# %%
# 딕셔너리를 통해 각 칼럼에 대한 데이터를 저장한 후
# 딕셔너리를 DataFrame 클래스의 생성자 인자로 넘겨주면 DataFrame 객체 생성

# %%
from pandas import Series, DataFrame

raw_data = {'col0': [1, 2, 3, 4, 5],
            'col1': [10, 20, 30, 40, 50],
            'col2': [100, 200, 300, 400, 500]}

data = DataFrame(raw_data)
print(data)
# Out:
#    col0  col1  col2
# 0     1    10   100
# 1     2    20   200
# 2     3    30   300
# 3     4    40   400
# 4     5    50   500

# %%
from pandas import Series, DataFrame

abcd = {'open':  [11650, 11100, 11200, 11100, 11000],
           'high':  [12100, 11800, 11200, 11100, 11150],
           'low' :  [11600, 11050, 10900, 10950, 10900],
           'close': [11900, 11600, 11000, 11100, 11050]}

abcd_day = DataFrame(abcd)
print(abcd_day)
# Out:
#     open   high    low  close
# 0  11650  12100  11600  11900
# 1  11100  11800  11050  11600
# 2  11200  11200  10900  11000
# 3  11100  11100  10950  11100
# 4  11000  11150  10900  11050

# %%
type(abcd_day)
# Out:
# pandas.core.frame.DataFrame

# %%
date = ['2020.02.29', '2020.02.26', '2020.02.25', '2020.02.24', '2020.02.23']
abcd_day = DataFrame(abcd, columns=['open', 'high', 'low', 'close'], index=date)

# %%
print(abcd_day)
# Out:
#              open   high    low  close
# 2020.02.29  11650  12100  11600  11900
# 2020.02.26  11100  11800  11050  11600
# 2020.02.25  11200  11200  10900  11000
# 2020.02.24  11100  11100  10950  11100
# 2020.02.23  11000  11150  10900  11050

# %% [markdown]
# ### DataFrame 로우(인덱스) ,칼럼 선택

# %%
 #'close' 칼럼에 대한 데이터만 DataFrame 객체로부터 얻는 경우
close = abcd_day['close']
print(close)
# Out:
# 2020.02.29    11900
# 2020.02.26    11600
# 2020.02.25    11000
# 2020.02.24    11100
# 2020.02.23    11050
# Name: close, dtype: int64

# %%
# DataFrame 객체의 로우에 접근하려면 loc 메서드를 사용해 인덱스 값을 넘겨주어야 함.
day_data = abcd_day.loc['2020.02.26']
print(day_data)
print(type(day_data))
# Out:
# open     11100
# high     11800
# low      11050
# close    11600
# Name: 2020.02.26, dtype: int64
# <class 'pandas.core.series.Series'>

# %%
# DataFrame 객체의 칼럼 이름과 인덱스 값을 확인하려면 각각 columns와 index 속성을 사용
print(abcd_day.columns)
print(abcd_day.index)
# Out:
# Index(['open', 'high', 'low', 'close'], dtype='object')
# Index(['2020.02.29', '2020.02.26', '2020.02.25', '2020.02.24', '2020.02.23'], dtype='object')

# %% [markdown]
# ### 텍스트 파일 만들기

# %%
#  CSV(Comma Separated Value) 포맷 입출력
#  --> CSV 파일 포맷은 데이터 값이 쉽표(comma)로 구분되는 텍스트 파일이다.

# CSV 파일 입력¶
# CSV 파일로부터 데이터를 읽어 데이터프레임을 만들 때는 pandas.read_csv 함수를 사용한다. 
# 함수의 입력값으로 파일 이름을 넣는다.

# %% [markdown]
# #### 1) %%writefile

# %%
# 판다스 불러오기
import pandas as pd

# %%
# %%writefile: 셀에 기입한 내용대로 텍스트 파일을 만드는 명령

# %%
# %%writefile stock_list.csv
# 삼성,현대차, 네이버
# 1, 100, 200,150
# 2, 110, 210,220
# 3, 120, 220,200
# Out:
# Overwriting stock_list.csv

# %% [markdown]
# #### 2) csv 파일 불러오기

# %%
# csv 파일 불러오기 
pd.read_csv('stock_list.csv')
# Out:
#     삼성  현대차   네이버
# 1  100  200   150
# 2  110  210   220
# 3  120  220   200

# %% [markdown]
# #### 3) csv 파일을 df로

# %%
# csv 파일을 df로
df = pd.read_csv('stock_list.csv')
df
# Out:
#     삼성  현대차   네이버
# 1  100  200   150
# 2  110  210   220
# 3  120  220   200

# %% [markdown]
# #### 4) csv파일 저장하기

# %%
df.to_csv('stock_list')

# %% [markdown]
# #### 파일 불러오기

# %%
df = pd.read_csv("./stock_list.csv")
df.head()
# Out:
#     삼성  현대차   네이버
# 1  100  200   150
# 2  110  210   220
# 3  120  220   200

# %% [markdown]
# #### 6) 웹 상의 CSV 파일 입력

# %%
# url을 이용하여 csv 파일을 다운하여 입력
df = pd.read_csv("https://raw.githubusercontent.com/datascienceschool/docker_rpython/master/data/titanic.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### 주식 데이터 받기 : 별도 자료 참고

# %% [markdown]
# ## FinanceDataReader을 이용한 분석
# #### https://pandas-datareader.readthedocs.io/en/latest/readers/index.html¶

# %%
# 한국 주식 가격, 미국주식 가격, 지수, 환율, 암호화폐 가격, 종목 리스팅 등 금융 데이터 수집 라이브러리
# FinanceData/FinanceDataReader: Financial data reader

# FinanceDataReader 사용자 안내서 적극 활용

# %%
# pandas-datareader 라는 이름의 독립 패키지 활용
# pandas_datareader 패키지의 DataReader라는 함수 : 웹 상의 데이터를 DataFrame 객체로 만드는 기능 제공

# %%
# finance-datareader 설치¶

# !pip install finance-datareader
# Out:
# Requirement already satisfied: finance-datareader in c:\users\jyb\anaconda3\lib\site-packages (0.9.50)
# Requirement already satisfied: lxml in c:\users\jyb\anaconda3\lib\site-packages (from finance-datareader) (4.9.1)
# Requirement already satisfied: pandas>=0.19.2 in c:\users\jyb\anaconda3\lib\site-packages (from finance-datareader) (1.4.4)
# Requirement already satisfied: requests-file in c:\users\jyb\anaconda3\lib\site-packages (from finance-datareader) (1.5.1)
# Requirement already satisfied: tqdm in c:\users\jyb\anaconda3\lib\site-packages (from finance-datareader) (4.64.1)
# Requirement already satisfied: requests>=2.3.0 in c:\users\jyb\anaconda3\lib\site-packages (from finance-datareader) (2.28.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jyb\anaconda3\lib\site-packages (from pandas>=0.19.2->finance-datareader) (2023.3)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\jyb\anaconda3\lib\site-packages (from pandas>=0.19.2->finance-datareader) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\jyb\anaconda3\lib\site-packages (from pandas>=0.19.2->finance-datareader) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jyb\anaconda3\lib\site-packages (from requests>=2.3.0->finance-datareader) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jyb\anaconda3\lib\site-packages (from requests>=2.3.0->finance-datareader) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\jyb\anaconda3\lib\site-packages (from requests>=2.3.0->finance-datareader) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jyb\anaconda3\lib\site-packages (from requests>=2.3.0->finance-datareader) (2023.5.7)
# Requirement already satisfied: six in c:\users\jyb\anaconda3\lib\site-packages (from requests-file->finance-datareader) (1.16.0)
# Requirement already satisfied: colorama in c:\users\jyb\anaconda3\lib\site-packages (from tqdm->finance-datareader) (0.4.5)

# %%
# 라이브러리 불러오기¶
# 데이터프레임을 활용한 다양한 활용을 위한 pandas 불러오기

import pandas as pd
import numpy as np

# %% [markdown]
# ### 한국거래소 상장종목 전체 가져오기

# %%
# FinanceDataReader 를 fdr 별칭으로 불러오는 방법으로
import FinanceDataReader as fdr

fdr.__version__
# Out:
# '0.9.50'

# %%
# 데이터를 갖고 오는 시장 지정하기
# KRX : KRX 종목 전체¶
# KOSPI : KOSPI 종목
# KOSDAQ : KOSDAQ 종목
# KONEX : KONEX 종목
# NASDAQ : 나스닥 종목
# NYSE : 뉴욕증권거래소 종목
# SP500 : S&P500 종목

# %%
#한국 거래소 상장종목 가져오기
data_krx = fdr.StockListing('KRX')
data_nasdaq = fdr.StockListing('NASDAQ')
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 4298/4298 [00:11<00:00, 384.26it/s]

# %%
# 데이터 행과열 확인하기
data_krx.shape
# Out:
# (2717, 17)

# %%
#data_krx의 전체적인 데이타의 특성정보를 확인할 수 있다.
data_krx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2717 entries, 0 to 2716
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Code         2717 non-null   object
#  1   ISU_CD       2717 non-null   object
#  2   Name         2717 non-null   object
#  3   Market       2717 non-null   object
#  4   Dept         2717 non-null   object
#  5   Close        2717 non-null   object
#  6   ChangeCode   2717 non-null   object
#  7   Changes      2717 non-null   int64
#  8   ChagesRatio  2717 non-null   float64
#  9   Open         2717 non-null   int64
#  10  High         2717 non-null   int64
#  11  Low          2717 non-null   int64
#  12  Volume       2717 non-null   int64
#  13  Amount       2717 non-null   int64
#  14  Marcap       2717 non-null   int64
#  15  Stocks       2717 non-null   int64
#  16  MarketId     2717 non-null   object
# dtypes: float64(1), int64(8), object(8)
# memory usage: 361.0+ KB

# %%
#data_krx의 전체적인 데이타의 기술통계값을 확인할 수 있다.
data_krx.describe()
# Out:
#             Changes  ChagesRatio           Open           High            Low  \
# count   2717.000000  2717.000000    2717.000000    2717.000000    2717.000000
# mean     -36.873758    -0.099301   21008.355539   21326.616857   20729.947000
# std      952.366407     2.863343   54013.041234   54632.260261   53424.057892
# min   -21000.000000   -14.950000       0.000000       0.000000       0.000000
# 25%      -90.000000    -1.110000    2880.000000    2940.000000    2850.000000
# 50%      -10.000000    -0.240000    6900.000000    7040.000000    6710.000000
# 75%       20.000000     0.330000   16850.000000   17220.000000   16600.000000
# max    17000.000000    30.000000  789000.000000  793000.000000  785000.000000
#
#              Volume        Amount        Marcap        Stocks
# count  2.717000e+03  2.717000e+03  2.717000e+03  2.717000e+03
# mean   7.566451e+05  5.412870e+09  8.999113e+11  4.176937e+07
# std    6.487861e+06  2.528198e+10  8.874017e+12  1.342801e+08
# min    0.000000e+00  0.000000e+00  1.120000e+09  1.098520e+05
# 25%    1.636700e+04  1.037596e+08  6.350573e+10  1.001386e+07
# 50%    6.516400e+04  4.296911e+08  1.267481e+11  1.952258e+07
# 75%    2.341990e+05  2.329294e+09  2.992365e+11  4.099696e+07
# max    2.223556e+08  5.959343e+11  4.083331e+14  5.969783e+09

# %%
# 컬럼확인
data_krx.columns
# Out:
# Index(['Code', 'ISU_CD', 'Name', 'Market', 'Dept', 'Close', 'ChangeCode',
#        'Changes', 'ChagesRatio', 'Open', 'High', 'Low', 'Volume', 'Amount',
#        'Marcap', 'Stocks', 'MarketId'],
#       dtype='object')

# %%
# 파일로 저장하고 불러오기¶
data_krx
# Out:
#         Code        ISU_CD      Name Market   Dept   Close ChangeCode  \
# 0     005930  KR7005930003      삼성전자  KOSPI          68400          3
# 1     373220  KR7373220003  LG에너지솔루션  KOSPI         581000          1
# 2     000660  KR7000660001    SK하이닉스  KOSPI          97500          2
# 3     207940  KR7207940008  삼성바이오로직스  KOSPI         790000          2
# 4     051910  KR7051910008      LG화학  KOSPI         722000          1
# ...      ...           ...       ...    ...    ...     ...        ...
# 2712  245450  KR7245450002    씨앤에스링크  KONEX  일반기업부    1799          1
# 2713  000547  KR7000542001   흥국화재2우B  KOSPI          17290          1
# 2714  288490  KR7288490006     나라소프트  KONEX  일반기업부      62          2
# 2715  322190  KR7322190000        베른  KONEX  일반기업부     145          2
# 2716  308700  KR7308700004       테크엔  KONEX  일반기업부     280          2
#
#       Changes  ChagesRatio    Open    High     Low   Volume        Amount  \
# 0           0         0.00   68100   68700   68000  6856111  468946827400
# 1        7000         1.22  574000  584000  572000   201167  116678982000
# 2        -400        -0.41   97400   97800   96300  1751207  169913329000
# 3       -2000        -0.25  789000  793000  785000    28864   22788980000
# 4        3000         0.42  719000  734000  716000   152122  110245808000
# ...       ...          ...     ...     ...     ...      ...           ...
# 2712       40         2.27    1799    1799    1799        1          1799
# 2713      120         0.70   16850   17290   16810      197       3332780
# 2714       -1        -1.59      62      65      59   123814       7488591
# 2715       -2        -1.36     145     145     145        5           725
# 2716       -8        -2.78     288     288     280     3551       1004168
#
#                Marcap      Stocks MarketId
# 0     408333126420000  5969782550      STK
# 1     135954000000000   234000000      STK
# 2      70980230587500   728002365      STK
# 3      56227460000000    71174000      STK
# 4      50967671646000    70592343      STK
# ...               ...         ...      ...
# 2712       2842348040     1579960      KNX
# 2713       2655744000      153600      STK
# 2714       2365114000    38147000      KNX
# 2715       1294153565     8925197      KNX
# 2716       1120000000     4000000      KNX
#
# [2717 rows x 17 columns]

# %%
# 파일 저장하고 불러오기
data_krx.to_csv('krx_data.csv')
pd.read_csv('krx_data.csv')
# Out:
#       Unnamed: 0    Code        ISU_CD      Name Market   Dept   Close  \
# 0              0  005930  KR7005930003      삼성전자  KOSPI    NaN   68400
# 1              1  373220  KR7373220003  LG에너지솔루션  KOSPI    NaN  581000
# 2              2  000660  KR7000660001    SK하이닉스  KOSPI    NaN   97500
# 3              3  207940  KR7207940008  삼성바이오로직스  KOSPI    NaN  790000
# 4              4  051910  KR7051910008      LG화학  KOSPI    NaN  722000
# ...          ...     ...           ...       ...    ...    ...     ...
# 2712        2712  245450  KR7245450002    씨앤에스링크  KONEX  일반기업부    1799
# 2713        2713  000547  KR7000542001   흥국화재2우B  KOSPI    NaN   17290
# 2714        2714  288490  KR7288490006     나라소프트  KONEX  일반기업부      62
# 2715        2715  322190  KR7322190000        베른  KONEX  일반기업부     145
# 2716        2716  308700  KR7308700004       테크엔  KONEX  일반기업부     280
#
#       ChangeCode  Changes  ChagesRatio    Open    High     Low   Volume  \
# 0              3        0         0.00   68100   68700   68000  6856111
# 1              1     7000         1.22  574000  584000  572000   201167
# 2              2     -400        -0.41   97400   97800   96300  1751207
# 3              2    -2000        -0.25  789000  793000  785000    28864
# 4              1     3000         0.42  719000  734000  716000   152122
# ...          ...      ...          ...     ...     ...     ...      ...
# 2712           1       40         2.27    1799    1799    1799        1
# 2713           1      120         0.70   16850   17290   16810      197
# 2714           2       -1        -1.59      62      65      59   123814
# 2715           2       -2        -1.36     145     145     145        5
# 2716           2       -8        -2.78     288     288     280     3551
#
#             Amount           Marcap      Stocks MarketId
# 0     468946827400  408333126420000  5969782550      STK
# 1     116678982000  135954000000000   234000000      STK
# 2     169913329000   70980230587500   728002365      STK
# 3      22788980000   56227460000000    71174000      STK
# 4     110245808000   50967671646000    70592343      STK
# ...            ...              ...         ...      ...
# 2712          1799       2842348040     1579960      KNX
# 2713       3332780       2655744000      153600      STK
# 2714       7488591       2365114000    38147000      KNX
# 2715           725       1294153565     8925197      KNX
# 2716       1004168       1120000000     4000000      KNX
#
# [2717 rows x 18 columns]

# %%
# 파일 저장하고 불러오기
data_krx.to_csv('krx_data.csv', encoding="utf-8-sig")
pd.read_csv('krx_data.csv')
# Out:
#       Unnamed: 0    Code        ISU_CD      Name Market   Dept   Close  \
# 0              0  005930  KR7005930003      삼성전자  KOSPI    NaN   68400
# 1              1  373220  KR7373220003  LG에너지솔루션  KOSPI    NaN  581000
# 2              2  000660  KR7000660001    SK하이닉스  KOSPI    NaN   97500
# 3              3  207940  KR7207940008  삼성바이오로직스  KOSPI    NaN  790000
# 4              4  051910  KR7051910008      LG화학  KOSPI    NaN  722000
# ...          ...     ...           ...       ...    ...    ...     ...
# 2712        2712  245450  KR7245450002    씨앤에스링크  KONEX  일반기업부    1799
# 2713        2713  000547  KR7000542001   흥국화재2우B  KOSPI    NaN   17290
# 2714        2714  288490  KR7288490006     나라소프트  KONEX  일반기업부      62
# 2715        2715  322190  KR7322190000        베른  KONEX  일반기업부     145
# 2716        2716  308700  KR7308700004       테크엔  KONEX  일반기업부     280
#
#       ChangeCode  Changes  ChagesRatio    Open    High     Low   Volume  \
# 0              3        0         0.00   68100   68700   68000  6856111
# 1              1     7000         1.22  574000  584000  572000   201167
# 2              2     -400        -0.41   97400   97800   96300  1751207
# 3              2    -2000        -0.25  789000  793000  785000    28864
# 4              1     3000         0.42  719000  734000  716000   152122
# ...          ...      ...          ...     ...     ...     ...      ...
# 2712           1       40         2.27    1799    1799    1799        1
# 2713           1      120         0.70   16850   17290   16810      197
# 2714           2       -1        -1.59      62      65      59   123814
# 2715           2       -2        -1.36     145     145     145        5
# 2716           2       -8        -2.78     288     288     280     3551
#
#             Amount           Marcap      Stocks MarketId
# 0     468946827400  408333126420000  5969782550      STK
# 1     116678982000  135954000000000   234000000      STK
# 2     169913329000   70980230587500   728002365      STK
# 3      22788980000   56227460000000    71174000      STK
# 4     110245808000   50967671646000    70592343      STK
# ...            ...              ...         ...      ...
# 2712          1799       2842348040     1579960      KNX
# 2713       3332780       2655744000      153600      STK
# 2714       7488591       2365114000    38147000      KNX
# 2715           725       1294153565     8925197      KNX
# 2716       1004168       1120000000     4000000      KNX
#
# [2717 rows x 18 columns]

# %%
# 파일 저장하고 불러오기
data_krx.to_csv('krx_data.csv', encoding="utf-8-sig", index=False)
pd.read_csv('krx_data.csv')
# Out:
#         Code        ISU_CD      Name Market   Dept   Close  ChangeCode  \
# 0     005930  KR7005930003      삼성전자  KOSPI    NaN   68400           3
# 1     373220  KR7373220003  LG에너지솔루션  KOSPI    NaN  581000           1
# 2     000660  KR7000660001    SK하이닉스  KOSPI    NaN   97500           2
# 3     207940  KR7207940008  삼성바이오로직스  KOSPI    NaN  790000           2
# 4     051910  KR7051910008      LG화학  KOSPI    NaN  722000           1
# ...      ...           ...       ...    ...    ...     ...         ...
# 2712  245450  KR7245450002    씨앤에스링크  KONEX  일반기업부    1799           1
# 2713  000547  KR7000542001   흥국화재2우B  KOSPI    NaN   17290           1
# 2714  288490  KR7288490006     나라소프트  KONEX  일반기업부      62           2
# 2715  322190  KR7322190000        베른  KONEX  일반기업부     145           2
# 2716  308700  KR7308700004       테크엔  KONEX  일반기업부     280           2
#
#       Changes  ChagesRatio    Open    High     Low   Volume        Amount  \
# 0           0         0.00   68100   68700   68000  6856111  468946827400
# 1        7000         1.22  574000  584000  572000   201167  116678982000
# 2        -400        -0.41   97400   97800   96300  1751207  169913329000
# 3       -2000        -0.25  789000  793000  785000    28864   22788980000
# 4        3000         0.42  719000  734000  716000   152122  110245808000
# ...       ...          ...     ...     ...     ...      ...           ...
# 2712       40         2.27    1799    1799    1799        1          1799
# 2713      120         0.70   16850   17290   16810      197       3332780
# 2714       -1        -1.59      62      65      59   123814       7488591
# 2715       -2        -1.36     145     145     145        5           725
# 2716       -8        -2.78     288     288     280     3551       1004168
#
#                Marcap      Stocks MarketId
# 0     408333126420000  5969782550      STK
# 1     135954000000000   234000000      STK
# 2      70980230587500   728002365      STK
# 3      56227460000000    71174000      STK
# 4      50967671646000    70592343      STK
# ...               ...         ...      ...
# 2712       2842348040     1579960      KNX
# 2713       2655744000      153600      STK
# 2714       2365114000    38147000      KNX
# 2715       1294153565     8925197      KNX
# 2716       1120000000     4000000      KNX
#
# [2717 rows x 17 columns]

# %%
# Name 컬럼 중 특정한 하나만 가져오는 경우
data_krx['Name']
# Out:
# 0           삼성전자
# 1       LG에너지솔루션
# 2         SK하이닉스
# 3       삼성바이오로직스
# 4           LG화학
#           ...
# 2712      씨앤에스링크
# 2713     흥국화재2우B
# 2714       나라소프트
# 2715          베른
# 2716         테크엔
# Name: Name, Length: 2717, dtype: object

# %%
# 0번째 행만 가져오는 경우
# 행인덱스를 가져올때는 .loc를 사용
# loc는 위치(locate)를 의미
data_krx.loc[0]
# Out:
# Code                    005930
# ISU_CD            KR7005930003
# Name                      삼성전자
# Market                   KOSPI
# Dept
# Close                    68400
# ChangeCode                   3
# Changes                      0
# ChagesRatio                0.0
# Open                     68100
# High                     68700
# Low                      68000
# Volume                 6856111
# Amount            468946827400
# Marcap         408333126420000
# Stocks              5969782550
# MarketId                   STK
# Name: 0, dtype: object

# %%
# df.loc[0] 의 type을 보는 경우
type(data_krx.loc[0])
# Out:
# pandas.core.series.Series

# %%
# 여러 컬럼을 지정할 때는 리스트 형태로 묶어주어야 함.
# 2차원 행렬은 대괄호가 [] 2개가 있다.
data_krx[['Name','Market']]
# Out:
#           Name Market
# 0         삼성전자  KOSPI
# 1     LG에너지솔루션  KOSPI
# 2       SK하이닉스  KOSPI
# 3     삼성바이오로직스  KOSPI
# 4         LG화학  KOSPI
# ...        ...    ...
# 2712    씨앤에스링크  KONEX
# 2713   흥국화재2우B  KOSPI
# 2714     나라소프트  KONEX
# 2715        베른  KONEX
# 2716       테크엔  KONEX
#
# [2717 rows x 2 columns]

# %%
# 여러 개의 행을 가져오는 경우
# [] 대괄호를 통해 리스트 형태로 묶어준다.
data_krx.loc[[0,3,5,7]]
# Out:
#      Code        ISU_CD      Name Market Dept   Close ChangeCode  Changes  \
# 0  005930  KR7005930003      삼성전자  KOSPI        68400          3        0
# 3  207940  KR7207940008  삼성바이오로직스  KOSPI       790000          2    -2000
# 5  006400  KR7006400006     삼성SDI  KOSPI       711000          1     1000
# 7  005380  KR7005380001       현대차  KOSPI       207000          2     -500
#
#    ChagesRatio    Open    High     Low   Volume        Amount  \
# 0         0.00   68100   68700   68000  6856111  468946827400
# 3        -0.25  789000  793000  785000    28864   22788980000
# 5         0.14  700000  713000  700000   112385   79632083000
# 7        -0.24  206000  208000  205500   265524   54873692000
#
#             Marcap      Stocks MarketId
# 0  408333126420000  5969782550      STK
# 3   56227460000000    71174000      STK
# 5   48891580830000    68764530      STK
# 7   43787021742000   211531506      STK

# %%
# FinanceDataReader 패키지의 data 모듈을 임포트한 후 
# 추가로 datetime이라는 모듈을 임포트 : datetime은 파이썬에서 날짜를 쉽게 표현하는 데 사용하는 모듈

# %%
# 2월과 3월을 입력할 때 02, 03이 아니라 2, 3으로 입력
import FinanceDataReader as fdr
import datetime
start = datetime.datetime(2022, 1, 3)
end = datetime.datetime(2022, 9, 1)

# %%
# DataReader 함수의 첫 번째 인자로는 조회할 종목 정보 입력
# KS : KOSPI 시장 , 
# 두 번째 인자로는 데이터를 가져올 원천(야후)에 대한 정보를 입력
# 조회 기간의 시작일과 종료일을 입력
sm = fdr.DataReader("005930", start, end)
sm
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2022-01-03  79400  79800  78200  78600  13502112  0.003831
# 2022-01-04  78800  79200  78300  78700  12427416  0.001272
# 2022-01-05  78800  79000  76400  77400  25470640 -0.016518
# 2022-01-06  76700  77600  76600  76900  12931954 -0.006460
# 2022-01-07  78100  78400  77400  78300  15163757  0.018205
# ...           ...    ...    ...    ...       ...       ...
# 2022-08-26  60300  60900  59900  60000   9499995  0.005025
# 2022-08-29  58700  58900  58600  58600   9841329 -0.023333
# 2022-08-30  58700  59000  58300  58800   9690044  0.003413
# 2022-08-31  58200  59900  58200  59700  14203512  0.015306
# 2022-09-01  58700  58900  58300  58400  14905777 -0.021776
#
# [165 rows x 6 columns]

# %%
# 데이터 가져오기 다른 방법
# datetime 모듈을 이용해 조회 기간을 입력하는 경우 외에도 조회 기간의 시작일과 종료일을 직접 입력해도 가능
# 이 경우에는 datetime과 달리 날짜에 0을 넣거나 빼도 무방
sm = fdr.DataReader("005930", "2022-01-03", "2022-09-01")
sm
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2022-01-03  79400  79800  78200  78600  13502112  0.003831
# 2022-01-04  78800  79200  78300  78700  12427416  0.001272
# 2022-01-05  78800  79000  76400  77400  25470640 -0.016518
# 2022-01-06  76700  77600  76600  76900  12931954 -0.006460
# 2022-01-07  78100  78400  77400  78300  15163757  0.018205
# ...           ...    ...    ...    ...       ...       ...
# 2022-08-26  60300  60900  59900  60000   9499995  0.005025
# 2022-08-29  58700  58900  58600  58600   9841329 -0.023333
# 2022-08-30  58700  59000  58300  58800   9690044  0.003413
# 2022-08-31  58200  59900  58200  59700  14203512  0.015306
# 2022-09-01  58700  58900  58300  58400  14905777 -0.021776
#
# [165 rows x 6 columns]

# %%
# 위 경우에는 datetime과 달리 날짜에 0을 넣거나 빼도 무방
sm = fdr.DataReader("005930", "2022-1-3", "2022-9-1")
sm
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2022-01-03  79400  79800  78200  78600  13502112  0.003831
# 2022-01-04  78800  79200  78300  78700  12427416  0.001272
# 2022-01-05  78800  79000  76400  77400  25470640 -0.016518
# 2022-01-06  76700  77600  76600  76900  12931954 -0.006460
# 2022-01-07  78100  78400  77400  78300  15163757  0.018205
# ...           ...    ...    ...    ...       ...       ...
# 2022-08-26  60300  60900  59900  60000   9499995  0.005025
# 2022-08-29  58700  58900  58600  58600   9841329 -0.023333
# 2022-08-30  58700  59000  58300  58800   9690044  0.003413
# 2022-08-31  58200  59900  58200  59700  14203512  0.015306
# 2022-09-01  58700  58900  58300  58400  14905777 -0.021776
#
# [165 rows x 6 columns]

# %% [markdown]
# ### 데이터를 시각적으로 표현

# %%
# 그래픽 종류
# line	line graph
# pie	pie chart
# scatter	scatter plot
# bar, barh	vertical, horizontal bar charts
# area	area plots
# box	box plot
# hexbin	hexbin plot
# hist	histogram
# kde, density	kernel density charts

# %%
import pandas_datareader.data as web
import datetime
start = datetime.datetime(2022, 1, 3)
end = datetime.datetime(2022, 9, 1)
sm = fdr.DataReader("005930", start, end)

# %%
# info 메서드를 호출하면 DataFrame 객체를 요약
sm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 165 entries, 2022-01-03 to 2022-09-01
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    165 non-null    int64
#  1   High    165 non-null    int64
#  2   Low     165 non-null    int64
#  3   Close   165 non-null    int64
#  4   Volume  165 non-null    int64
#  5   Change  165 non-null    float64
# dtypes: float64(1), int64(5)
# memory usage: 9.0 KB

# %%
# 그래프를 그릴 때는 matplotlib라는 패키지를 주로 사용 
# 그래프는 matplotlib 패키지의 pyplot이라는 모듈 사용

import matplotlib.pyplot as plt

# %%
# pyplot 모듈에는 그래프를 그리는 plot 함수가 내재
# plot 함수를 호출 : 그래프로 표현하려는 데이터를 인자로 전달하면 됨.
# DataFrame에서 'Close'라는 칼럼데이터를 전달
# 그래프를 화면에 출력하기 위해 show 메서드를 호출

# %%
plt.plot(sm['Close'])

# %%
plt.plot(sm['Close'])
plt.show()

# %% [markdown]
# ### 기술적 분석지표로 이동평균선

# %%
# pandas를 이용해 이동평균을 계산
# 주가이동평균 : 일정 기간의 주가를 산술 평균한 값
# 5일로 사용한 것이 5일 주가이동평균이고 이를 연결한 것이 5일 주가이동평균 선
# 주가이동평균을 계산하는 데 사용되는 값은 수정 종가(Adjusted Closing Price)

# %%
import pandas as pd
import FinanceDataReader as fdr
sm = fdr.DataReader("005930", "2022-01-03", "2022-09-01")

# %%
sm
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2022-01-03  79400  79800  78200  78600  13502112  0.003831
# 2022-01-04  78800  79200  78300  78700  12427416  0.001272
# 2022-01-05  78800  79000  76400  77400  25470640 -0.016518
# 2022-01-06  76700  77600  76600  76900  12931954 -0.006460
# 2022-01-07  78100  78400  77400  78300  15163757  0.018205
# ...           ...    ...    ...    ...       ...       ...
# 2022-08-26  60300  60900  59900  60000   9499995  0.005025
# 2022-08-29  58700  58900  58600  58600   9841329 -0.023333
# 2022-08-30  58700  59000  58300  58800   9690044  0.003413
# 2022-08-31  58200  59900  58200  59700  14203512  0.015306
# 2022-09-01  58700  58900  58300  58400  14905777 -0.021776
#
# [165 rows x 6 columns]

# %%
 # tail 메서드를 호출해서 끝부분에 위치하는 5개의 데이터를 확인
sm.tail()
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2022-08-26  60300  60900  59900  60000   9499995  0.005025
# 2022-08-29  58700  58900  58600  58600   9841329 -0.023333
# 2022-08-30  58700  59000  58300  58800   9690044  0.003413
# 2022-08-31  58200  59900  58200  59700  14203512  0.015306
# 2022-09-01  58700  58900  58300  58400  14905777 -0.021776

# %%
 # head 메서드를 호출해서 끝부분에 위치하는 5개의 데이터를 확인
sm.head()
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2022-01-03  79400  79800  78200  78600  13502112  0.003831
# 2022-01-04  78800  79200  78300  78700  12427416  0.001272
# 2022-01-05  78800  79000  76400  77400  25470640 -0.016518
# 2022-01-06  76700  77600  76600  76900  12931954 -0.006460
# 2022-01-07  78100  78400  77400  78300  15163757  0.018205

# %%
sm
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2022-01-03  79400  79800  78200  78600  13502112  0.003831
# 2022-01-04  78800  79200  78300  78700  12427416  0.001272
# 2022-01-05  78800  79000  76400  77400  25470640 -0.016518
# 2022-01-06  76700  77600  76600  76900  12931954 -0.006460
# 2022-01-07  78100  78400  77400  78300  15163757  0.018205
# ...           ...    ...    ...    ...       ...       ...
# 2022-08-26  60300  60900  59900  60000   9499995  0.005025
# 2022-08-29  58700  58900  58600  58600   9841329 -0.023333
# 2022-08-30  58700  59000  58300  58800   9690044  0.003413
# 2022-08-31  58200  59900  58200  59700  14203512  0.015306
# 2022-09-01  58700  58900  58300  58400  14905777 -0.021776
#
# [165 rows x 6 columns]

# %%
# 5일 이평 계산 : 수정 종가에 대해 5일 주가 이동평균을 계산
# 5일 이평 변수명 지정 : ma5 

ma5 = sm['Close'].rolling(window=5).mean()

# %%
# 객체의 타입을 보면 pandas의 Series임을 확인
type(ma5)
# Out:
# pandas.core.series.Series

# %%
ma5
# Out:
# Date
# 2022-01-03        NaN
# 2022-01-04        NaN
# 2022-01-05        NaN
# 2022-01-06        NaN
# 2022-01-07    77980.0
#                ...
# 2022-08-26    59560.0
# 2022-08-29    59280.0
# 2022-08-30    59220.0
# 2022-08-31    59360.0
# 2022-09-01    59100.0
# Name: Close, Length: 165, dtype: float64

# %%
# 최근 10일 종가 확인
ma5.tail(10)
# Out:
# Date
# 2022-08-19    60800.0
# 2022-08-22    60760.0
# 2022-08-23    60380.0
# 2022-08-24    60100.0
# 2022-08-25    59740.0
# 2022-08-26    59560.0
# 2022-08-29    59280.0
# 2022-08-30    59220.0
# 2022-08-31    59360.0
# 2022-09-01    59100.0
# Name: Close, dtype: float64

# %%
# 공휴일  일자의 데이터를 DataFrame 객체에서 제거 필요 한 경우
# DataFrame 객체의 칼럼을 어떤 값과 비교하면 칼럼(Series 객체)에 있는 모든 값에 비교 연산자가 적용

sm['Volume'] != 0
# 거래량이 0이었던 일자에는 False 값이, 그렇지 않은 일자에는 True가 반환
# DataFrame 객체에서 특정 조건을 만족하는 데이터만 쉽게 축출
# Out:
# Date
# 2022-01-03    True
# 2022-01-04    True
# 2022-01-05    True
# 2022-01-06    True
# 2022-01-07    True
#               ...
# 2022-08-26    True
# 2022-08-29    True
# 2022-08-30    True
# 2022-08-31    True
# 2022-09-01    True
# Name: Volume, Length: 165, dtype: bool

# %%
# DataFrame 객체에서 특정 조건을 만족하는 데이터만 쉽게 cnrcnf
# tail 메서드를 이용해 new_sm 라는 DataFrame 객체의 값을 확인
new_sm = sm[sm['Volume'] !=0]
new_sm.tail(5)
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2022-08-26  60300  60900  59900  60000   9499995  0.005025
# 2022-08-29  58700  58900  58600  58600   9841329 -0.023333
# 2022-08-30  58700  59000  58300  58800   9690044  0.003413
# 2022-08-31  58200  59900  58200  59700  14203512  0.015306
# 2022-09-01  58700  58900  58300  58400  14905777 -0.021776

# %%
# 공휴일 데이터가 제거된 DataFrame 객체가 준비됐으니 다시 5일 이동평균 값을 계산 
# 계산 후에 tail 메서드를 사용해 끝에 위치한 10개의 데이터만 화면에 출력
MA5 = new_sm['Close'].rolling(window=5).mean()
MA5.tail(10)
# Out:
# Date
# 2022-08-19    60800.0
# 2022-08-22    60760.0
# 2022-08-23    60380.0
# 2022-08-24    60100.0
# 2022-08-25    59740.0
# 2022-08-26    59560.0
# 2022-08-29    59280.0
# 2022-08-30    59220.0
# 2022-08-31    59360.0
# 2022-09-01    59100.0
# Name: Close, dtype: float64

# %%
#계산된 5일 주가이동평균 값을 좀 더 쉽게 관리하기 위해 DataFrame 객체의 새로운 칼럼으로 추가
#DataFrame에 칼럼을 추가하려면 insert 메서드를 사용
#insert 메서드의 첫 번째 인자로는 칼럼이 추가될 위치, 두 번째 인자로는 칼럼의 이름을, 세 번째 인자로는 DataFrame 객체에 추가할 데이터를 전달

MA5 = new_sm['Close'].rolling(window=5).mean()
MA5.tail(10)
# Out:
# Date
# 2022-08-19    60800.0
# 2022-08-22    60760.0
# 2022-08-23    60380.0
# 2022-08-24    60100.0
# 2022-08-25    59740.0
# 2022-08-26    59560.0
# 2022-08-29    59280.0
# 2022-08-30    59220.0
# 2022-08-31    59360.0
# 2022-09-01    59100.0
# Name: Close, dtype: float64

# %%
MA5 =  new_sm['Close'].rolling(window=5).mean()
new_sm.insert(len(new_sm.columns), "MA5", ma5)
new_sm.tail(5)
# Out:
#              Open   High    Low  Close    Volume    Change      MA5
# Date
# 2022-08-26  60300  60900  59900  60000   9499995  0.005025  59560.0
# 2022-08-29  58700  58900  58600  58600   9841329 -0.023333  59280.0
# 2022-08-30  58700  59000  58300  58800   9690044  0.003413  59220.0
# 2022-08-31  58200  59900  58200  59700  14203512  0.015306  59360.0
# 2022-09-01  58700  58900  58300  58400  14905777 -0.021776  59100.0

# %%
# rolling_mean 함수의 두 번째 인자로 20, 60, 120의 값을 전달하면 20, 60, 120일 이동평균 값 역시 쉽게 계산
# 20, 60, 120일 이동평균 값 역시 DataFrame 객체의 칼럼으로 추가

ma20 = new_sm['Close'].rolling(window=20).mean()
ma60 = new_sm['Close'].rolling(window=60).mean()
ma120 = new_sm['Close'].rolling(window=120).mean()
new_sm.insert(len(new_sm.columns), "MA20", ma20)
new_sm.insert(len(new_sm.columns), "MA60", ma60)
new_sm.insert(len(new_sm.columns), "MA120", ma120)

# %%
ma20
# Out:
# Date
# 2022-01-03        NaN
# 2022-01-04        NaN
# 2022-01-05        NaN
# 2022-01-06        NaN
# 2022-01-07        NaN
#                ...
# 2022-08-26    60515.0
# 2022-08-29    60375.0
# 2022-08-30    60250.0
# 2022-08-31    60150.0
# 2022-09-01    60005.0
# Name: Close, Length: 165, dtype: float64

# %% [markdown]
# ### 그래프 종류
# #### https://en.wikipedia.org/wiki/Plot_(graphics)#Types%20of%20plots

# %%
# 대표적 그래프 소개
# Line chart : 수치형 관찰값들을 서로 선으로 연결한 그림
# Histogram : 수치형 자료의 확률분포를 나타냄
    
# Bar chart (Bar plot) : 막대그래프-->  각 범주(그룹)에 해당하는 수치형 값을 사각형의 높이로 표시 함.
# Pie chart 
# Scatter plot : 두 관측치(컬럼값)을 2차원 평면에 점으로 대응시킨 그림
# Box plot (Box-Whisker plot상자그림): 수치형 자료의 확률분포를 대표값들을 이용하여 간단히 나타냄
# Violin plot : boxplot과 비슷하게 데이터의 확률밀도를 시각화
# Heat map: 수치형 행렬에서 각 셀의 값을 색깔로 변환하여 나타낸 그림(보통 값이 커지면 빨간색, 작으면 파란색으로 표현)

# %%
# 주가이동평균선 그리기

# %%
# matplotlib 패키지의 pyplot 모듈 임포트
import matplotlib.pyplot as plt

# %%
# plot 함수를 사용해 그래프를 그리기
# 각 그래프가 서로 구분될 수 있도록 범례 추가 
# 범례 만들기 : 그래프에 label 인자 사용

# %%
# 수정 종가 그래프를 그리기 위해 label 인자에 'Adj Close'를 전달

# %%
plt.plot(new_sm.index, new_sm['Close'], label="Close")

# %%
plt.plot(new_sm.index, new_sm['MA20'], label="MA20")

# %%
plt.plot(new_sm.index, new_sm['MA5'], label="MA5")
plt.plot(new_sm.index, new_sm['MA20'], label="MA20")
plt.plot(new_sm.index, new_sm['MA60'], label="MA60")
plt.plot(new_sm.index, new_sm['MA120'], label="MA120")

#범례를 표시하기 위해 legend 함수를 호출
# loc 인자를 통해 범례 표시 위치를 지정 가능
# label 을 입력해주고, plt.legend() 를 실행해서 자동으로 범례를 만드는 방법
# 범례가 적절한 위치에 자동으로 출력되게 하려면 loc='best' 옵션 사용 : 기본설정값은 loc='best' 로서 컴퓨터가 장 적절한 여백을 가지는
# 그래프의 값을 좀 더 편리하게 확인하기 위한 격자(grid)를 표시하려면 grid 함수를 호출

plt.legend(loc='best')
plt.grid()
plt.show()

# 범례의 폰트 크기(fontsize), 
# 범례의 배경 색깔(facecolor, 기본설정값은 'white'), 
# 범례의 테두리선 색깔(edgecolor), 
# 범례 상자의 그림자 여부(shadow, 기본설정값은 'False') 등도 사용

# %%
# Python matplotlib 모듈을 사용해서 그래프를 그렸을 때 범례를 추가 4가지 방법
# (1) 범례 추가하기 
#   : legend(), legend(handles, labels), legend(handles=handles), legend(labels)
# (2) 범례 스타일 설정하기   : location, fontsize, facecolor, edgecolor, shadow

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(1)
x = np.arange(100)
y1 = np.random.normal(0, 1, 100)
y2 = np.random.normal(0, 1, 100).cumsum()

## 1. Automatic detection of elements to be shown in the legend
## 1-1. label
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(1, 1, 1)

## labels: A list of labels to show next to the artists. 
ax.plot(x, y1, 'b-', label='Com 1')
ax.plot(x, y2, 'r--', label='Com 2')
ax.legend()
plt.show()

# %%
 # 종합 : 삼성전자 이동평균선 그리기

# %%
import pandas as pd
import FinanceDataReader as fdr
import matplotlib.pyplot as plt

# Yahoo에서 삼성전자 가져오기
sm = fdr.DataReader("005930", "2022-01-01", "2022-09-01")
new_sm = sm[sm['Volume']!=0]

# Moving average
ma5 = new_sm['Close'].rolling(window=5).mean()
ma20 = new_sm['Close'].rolling(window=20).mean()
ma60 = new_sm['Close'].rolling(window=60).mean()
ma120 = new_sm['Close'].rolling(window=120).mean()

# Insert columns
new_sm.insert(len(new_sm.columns), "MA5", ma5)
new_sm.insert(len(new_sm.columns), "MA20", ma20)
new_sm.insert(len(new_sm.columns), "MA60", ma60)
new_sm.insert(len(new_sm.columns), "MA120", ma120)

# Plot
plt.plot(new_sm.index, new_sm['Close'], label='Close')
plt.plot(new_sm.index, new_sm['MA5'], label='MA5')
plt.plot(new_sm.index, new_sm['MA20'], label='MA20')
plt.plot(new_sm.index, new_sm['MA60'], label='MA60')
plt.plot(new_sm.index, new_sm['MA120'], label='MA120')

plt.legend(loc="best")
plt.grid()
plt.show()

# %% [markdown]
# #### Pandas 모듈을 이용한 그래프 그리기

# %%
# Python 그래픽 라이브러리
# Pandas 그래픽 모듈
# matplotlib: 저수준의 그래프
# Seaborn 패키지 : matplotlib기반으로 만들어진 고수준의 그래프를 그려주는 라이브러리

# %%
# methods	그래픽 종류
# line	line graph
# pie	pie chart
# scatter	scatter plot
# bar, barh	vertical, horizontal bar charts
# area	area plots
# box	box plot
# hexbin	hexbin plot
# hist	histogram
# kde, density	kernel density charts
